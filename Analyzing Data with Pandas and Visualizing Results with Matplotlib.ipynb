# %%
import pandas as pd  # For data manipulation and analysis
import numpy as np   # For numerical operations
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns  # For advanced data visualization

# %%
data = pd.read_excel(r'C:\Users\USER\Documents\ORIGINAL DATA DRY SEASON AT PYAKASA STAFF PREMESIS.xlsx')

# %%
data.head()
# Out:
#   ORIGINAL DRY SEASON DATA FOR PYAKASA STAFF PREMESIS Unnamed: 1 Unnamed: 2  \
# 0                                                NaN         NaN        NaN
# 1                                                NaN         NaN        NaN
# 2                                               TIME       PM1.0      PM2.5
# 3                                                  2          13         20
# 4                                                  4          12         16
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2       PM10         CO        H2S        CH4       TVOC       HCHO
# 3         23          0          0          0          0          0
# 4         18          0          0          0          0          0

# %%
# Drop rows with all NaN values
data.dropna(how='all', inplace=True)

# %%
data.head()
# Out:
#   ORIGINAL DRY SEASON DATA FOR PYAKASA STAFF PREMESIS Unnamed: 1 Unnamed: 2  \
# 2                                               TIME       PM1.0      PM2.5
# 3                                                  2          13         20
# 4                                                  4          12         16
# 5                                                  6          16         22
# 6                                                  8          19         25
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 2       PM10         CO        H2S        CH4       TVOC       HCHO
# 3         23          0          0          0          0          0
# 4         18          0          0          0          0          0
# 5         24          0          0          0          0          0
# 6         30          0          0          0          0          0

# %%
data.columns = data.iloc[0]
data = data[0:]

# %%
data.head(10)
# Out:
# 2   TIME  PM1.0  PM2.5  PM10  CO  H2S  CH4  TVOC   HCHO
# 2   TIME  PM1.0  PM2.5  PM10  CO  H2S  CH4  TVOC   HCHO
# 3      2     13     20    23   0    0    0     0      0
# 4      4     12     16    18   0    0    0     0      0
# 5      6     16     22    24   0    0    0     0      0
# 6      8     19     25    30   0    0    0     0      0
# 7     10     22     29    33   0    0    0     0      0
# 8     12     41     54    62   0    0    0     0      0
# 9     14     11     15    17   0    0    0     0  0.033
# 10    16     17     23    26   0    0    0     0      0
# 11    18     15     21    23   0    0    0     0      0

# %%
# Reset the index
data.reset_index(drop=True, inplace=True)

# %%
# Remove the first row after setting the header (which is a duplicate header)
data = data.drop(index=0)  # Drop the first row (index 0)

# %%
data.head(10)
# Out:
# 2  TIME PM1.0 PM2.5 PM10 CO H2S CH4   TVOC   HCHO
# 1     2    13    20   23  0   0   0      0      0
# 2     4    12    16   18  0   0   0      0      0
# 3     6    16    22   24  0   0   0      0      0
# 4     8    19    25   30  0   0   0      0      0
# 5    10    22    29   33  0   0   0      0      0
# 6    12    41    54   62  0   0   0      0      0
# 7    14    11    15   17  0   0   0      0  0.033
# 8    16    17    23   26  0   0   0      0      0
# 9    18    15    21   23  0   0   0      0      0
# 10   20    11    16   18  0   0   0  0.001  0.008

# %%
# Step 1: Calculate Mean
mean_values = data.mean()
print("Mean values:\n", mean_values)

# Step 2: Calculate Median
median_values = data.median()
print("\nMedian values:\n", median_values)

# Step 3: Calculate Standard Deviation
std_dev_values = data.std()
print("\nStandard Deviation values:\n", std_dev_values)
# Out:
# Mean values:
#  2
# TIME     101.00000
# PM1.0     14.12000
# PM2.5     19.28000
# PM10      21.89000
# CO         0.83000
# H2S        0.00000
# CH4        0.00000
# TVOC       0.00167
# HCHO       0.00197
# dtype: float64
#
# Median values:
#  2
# TIME     101.0
# PM1.0     12.0
# PM2.5     16.0
# PM10      18.0
# CO         0.0
# H2S        0.0
# CH4        0.0
# TVOC       0.0
# HCHO       0.0
# dtype: float64
#
# Standard Deviation values:
#  2
# TIME     58.022984
# PM1.0     7.471535
# PM2.5    10.013203
# PM10     11.717978
# CO        1.101468
# H2S       0.000000
# CH4       0.000000
# TVOC      0.014582
# HCHO      0.012673
# dtype: float64

# %%
# Display the column names
print(data.columns)
# Out:
# Index(['TIME', 'PM1.0', 'PM2.5', 'PM10', 'CO', 'H2S', 'CH4', 'TVOC', 'HCHO'], dtype='object', name=2)

# %%
# Step 2: Group by the 'TIME' column and compute the mean of 'PM1.0'
grouped_pm = data.groupby('TIME')['PM1.0'].mean().reset_index()

# Display the results
print(grouped_pm)
# Out:
#     TIME  PM1.0
# 0      2   13.0
# 1      4   12.0
# 2      6   16.0
# 3      8   19.0
# 4     10   22.0
# ..   ...    ...
# 95   192    8.0
# 96   194   16.0
# 97   196   12.0
# 98   198   12.0
# 99   200    9.0
#
# [100 rows x 2 columns]

# %%
# Step 2: Group by the 'TIME' column and compute the mean of 'PM2.5'
grouped_pm = data.groupby('TIME')['PM2.5'].mean().reset_index()

# Display the results
print(grouped_pm)
# Out:
#     TIME  PM2.5
# 0      2   20.0
# 1      4   16.0
# 2      6   22.0
# 3      8   25.0
# 4     10   29.0
# ..   ...    ...
# 95   192   11.0
# 96   194   21.0
# 97   196   16.0
# 98   198   17.0
# 99   200   13.0
#
# [100 rows x 2 columns]

# %%
# Step 2: Group by the 'TIME' column and compute the mean of 'PM2.5'
grouped_pm = data.groupby('TIME')['PM10'].mean().reset_index()

# Display the results
print(grouped_pm)
# Out:
#     TIME  PM10
# 0      2  23.0
# 1      4  18.0
# 2      6  24.0
# 3      8  30.0
# 4     10  33.0
# ..   ...   ...
# 95   192  12.0
# 96   194  24.0
# 97   196  18.0
# 98   198  19.0
# 99   200  15.0
#
# [100 rows x 2 columns]

# %%
# Step 2: Group by the 'TIME' column and compute the mean of 'PM2.5'
grouped_CO = data.groupby('TIME')['CO'].mean().reset_index()

# Display the results
print(grouped_CO)
# Out:
#     TIME   CO
# 0      2  0.0
# 1      4  0.0
# 2      6  0.0
# 3      8  0.0
# 4     10  0.0
# ..   ...  ...
# 95   192  0.0
# 96   194  0.0
# 97   196  0.0
# 98   198  0.0
# 99   200  0.0
#
# [100 rows x 2 columns]

# %%
# Line Chart
plt.figure(figsize=(10, 6))
plt.plot(data['TIME'], data['PM1.0'], marker='o')
plt.title('PM1.0 Trends Over Time')
plt.xlabel('Time')
plt.ylabel('PM1.0 Concentration')
plt.grid()
plt.show()

# %%
# Histogram
plt.figure(figsize=(10, 6))
plt.hist(data['PM10'], bins=20, color='blue', alpha=0.7)
plt.title('Distribution of PM10 Concentrations')
plt.xlabel('PM10 Concentration')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(10, 6))
plt.scatter(data['PM2.5'], data['PM10'], alpha=0.6, color='orange')
plt.title('Scatter Plot of PM2.5 vs PM10')
plt.xlabel('PM2.5 Concentration')
plt.ylabel('PM10 Concentration')
plt.grid()
plt.show()

# %%
data = pd.read_excel(r'C:\Users\USER\Documents\ORIGINAL DATA DRY SEASON AT PYAKASA STAFF PREMESIS.xlsx')

# %%
data.head()
# Out:
#   ORIGINAL DRY SEASON DATA FOR PYAKASA STAFF PREMESIS Unnamed: 1 Unnamed: 2  \
# 0                                                NaN         NaN        NaN
# 1                                                NaN         NaN        NaN
# 2                                               TIME       PM1.0      PM2.5
# 3                                                  2          13         20
# 4                                                  4          12         16
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2       PM10         CO        H2S        CH4       TVOC       HCHO
# 3         23          0          0          0          0          0
# 4         18          0          0          0          0          0

# %%
# Drop rows with all NaN values
data.dropna(how='all', inplace=True)

# %%
data.head()
# Out:
#   ORIGINAL DRY SEASON DATA FOR PYAKASA STAFF PREMESIS Unnamed: 1 Unnamed: 2  \
# 2                                               TIME       PM1.0      PM2.5
# 3                                                  2          13         20
# 4                                                  4          12         16
# 5                                                  6          16         22
# 6                                                  8          19         25
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 2       PM10         CO        H2S        CH4       TVOC       HCHO
# 3         23          0          0          0          0          0
# 4         18          0          0          0          0          0
# 5         24          0          0          0          0          0
# 6         30          0          0          0          0          0

# %%
data.columns = data.iloc[0]
data = data[0:]

# %%
data.head()
# Out:
# 2  TIME  PM1.0  PM2.5  PM10  CO  H2S  CH4  TVOC  HCHO
# 2  TIME  PM1.0  PM2.5  PM10  CO  H2S  CH4  TVOC  HCHO
# 3     2     13     20    23   0    0    0     0     0
# 4     4     12     16    18   0    0    0     0     0
# 5     6     16     22    24   0    0    0     0     0
# 6     8     19     25    30   0    0    0     0     0

# %%
# Reset the index
data.reset_index(drop=True, inplace=True)

# %%
# Remove the first row after setting the header (which is a duplicate header)
data = data.drop(index=0)  # Drop the first row (index 0)

# %%
data.head()
# Out:
# 2 TIME PM1.0 PM2.5 PM10 CO H2S CH4 TVOC HCHO
# 1    2    13    20   23  0   0   0    0    0
# 2    4    12    16   18  0   0   0    0    0
# 3    6    16    22   24  0   0   0    0    0
# 4    8    19    25   30  0   0   0    0    0
# 5   10    22    29   33  0   0   0    0    0

# %%
# Ensure TIME is treated as integer
data['TIME'] = data['TIME'].astype(int)

# Check if 'PM2.5' exists
if 'PM2.5' in data.columns:
    # Bar Chart for PM2.5
    plt.figure(figsize=(10, 6))
    sns.barplot(x=data['TIME'], y=data['PM2.5'], palette='viridis')
    plt.title('PM2.5 Concentration Over Time')
    plt.xlabel('Time (Integer Values)')
    plt.ylabel('PM2.5 Concentration')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
